# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load and show first 5 rows
df = pd.read_csv("dragon.csv")
print(df.head())

api.dataset_download_files('yasserh/housing-prices-dataset', path='housing_data', unzip=True)


import pandas as pd

# Load and show the first 5 rows from dragon.csv
df = pd.read_csv("dragon.csv")
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# Dataset URL: https://www.kaggle.com/datasets/yasserh/housing-prices-dataset
# ...

# %%
#understand the data
data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
data.shape
# Out:
# (129971, 14)

# %%
#cleaning the data
data.nunique()
# Out:
# Unnamed: 0               129971
# country                      43
# description              119955
# designation               37979
# points                       21
# price                       390
# province                    425
# region_1                   1229
# region_2                     17
# taster_name                  19
# taster_twitter_handle        15
# title                    118840
# variety                     707
# winery                    16757
# dtype: int64

# %%
data['province'].unique()
# Out:
# array(['Sicily & Sardinia', 'Douro', 'Oregon', 'Michigan',
#        'Northern Spain', 'Alsace', 'Rheinhessen', 'California', 'Mosel',
#        'Other', 'Mendoza Province', 'Virginia', 'Beaujolais',
#        'Colchagua Valley', 'Southern Italy', 'Maule Valley', 'Bordeaux',
#        'Maipo Valley', 'Washington', 'Central Italy', 'Champagne',
#        'Burgundy', 'South Australia', 'Tejo', 'Rapel Valley', 'Galicia',
#        'France Other', 'Tuscany', 'Burgenland', 'New York',
#        'Leyda Valley', 'Piedmont', 'Stellenbosch',
#        'Simonsberg-Stellenbosch', 'Walker Bay', 'Alentejano',
#        'Central Spain', 'Southwest France', 'Aconcagua Valley',
#        'Loncomilla Valley', 'Marlborough', 'Northeastern Italy',
#        'Casablanca Valley', 'Veneto', 'Western Cape', 'Judean Hills',
#        'Alentejo', 'Coastal Region', 'Rhône Valley', 'Galilee',
#        'Beira Atlantico', 'Tokaj', 'Leithaberg', 'Santorini', 'Kremstal',
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
columns_to_drop = ['bathrooms', 'prefarea']
available_cols = df.columns.tolist()

# Only drop columns that exist
drop_cols = [col for col in columns_to_drop if col in available_cols]

dragon = df.drop(drop_cols, axis=1)
print("✅ Dropped:", drop_cols)
# Out:
# ✅ Dropped: ['bathrooms', 'prefarea']

# %%
dragon.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking',
#        'furnishingstatus'],
#       dtype='object')

# %%
dragon.shape
# Out:
# (545, 11)

# %%
#Enable the new behavior globally
pd.set_option("future.no_silent_downcasting",True)
df = pd.DataFrame(dragon)
df.replace({'yes': 1, 'no': 0}, inplace=True)

# %%
# Analyze only numeric columns
numeric_dragon = dragon.select_dtypes(include=[np.number])
corelation = numeric_dragon.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(dragon)

# %%
sns.relplot(x='area' , y='price' , hue='stories', data = dragon)
